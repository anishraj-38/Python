# %%
a={"4","a","b","b","c"}
print(a)
print(len(a))
# Out:
# {'c', 'a', 'b', '4'}
# 4

# %%
a={'a','b','c','d'}
b={1,2,3,4}
c={1.1,2.2,3.3,4.4}
d={True,False,True,True}

print(a,b,c,d)
# Out:
# {'c', 'a', 'b', 'd'} {1, 2, 3, 4} {1.1, 2.2, 3.3, 4.4} {False, True}
