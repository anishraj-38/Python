# %% [markdown]
# <a href="https://colab.research.google.com/github/anishraj-38/Python/blob/main/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x1=[1,2,3,4,5]
y1=[1,2,3,4,5]
plt.plot(x1,y1)
plt.show()
sns.lineplot(x=x1,y=y1)
plt.show()

# %%
x1=[1,2,3,4,5]
y1=[1,2,3,4,5]
df=pd.DataFrame({"x":x1,'y':y1})
df
sns.lineplot(x="x",y="y",data=df)
plt.show()

# %%
df=pd.read_csv("/content/penguins.csv")
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
df1=sns.load_dataset("penguins")

# %%
df1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.lineplot(x="bill_length_mm",y="flipper_length_mm",data=df1,hue="sex",palette="rocket_r",style="sex",markers=["o",">"])
plt.show()

# %%
df1=sns.load_dataset("penguins").head(20)
sns.lineplot(x="bill_length_mm",y="flipper_length_mm",data=df1,hue='sex',style='sex',markers=['o','<'])
plt.grid()
plt.show()

# %% [markdown]
# Bar Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df1=sns.load_dataset("penguins")
sns.barplot(data=df1)
# Out:
# <Axes: >

# %%
sns.barplot(x=df1.island,y=df1.bill_length_mm)
plt.show()

# %%
sns.barplot(x='island',y='bill_length_mm',data=df1,hue='sex')
plt.show()

# %%
order1=['Torgersen','Biscoe','Dream']
sns.barplot(x='island',y='bill_length_mm',data=df1,hue='sex',order=order1)
plt.show()

# %%
order1=['Torgersen','Biscoe','Dream']
sns.barplot(x='island',y='bill_length_mm',data=df1,hue='sex',order=order1,hue_order=['Female','Male'])
plt.show()

# %%
order1=['Torgersen','Biscoe','Dream']
sns.barplot(x='island',y='bill_length_mm',data=df1,hue='sex',order=order1,saturation=0.5)
plt.show()

# %%
#Histogram Graph

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x=[1,2,3,4,34,23]
sns.histplot(x)
plt.show()

# %%
sns.displot(df1['bill_depth_mm'],bins=[0,5,10,15,20,25,30], kde=True)
plt.show()
